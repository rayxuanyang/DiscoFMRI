# %%
import os
import pandas as pd
Dir_github = '/work/desai-lab/xuanyang/Project/Semantic/analysis/FactorAnalysis/github'
project = 'FactorAnalysis_fMRI'

# %%
mastersheetFile = '/work/desai-lab/xuanyang/Project/Semantic/dissemination/github/DiscoFMRI/scripts/fMRI/master_subject_10stories_highacc.csv'
df_master = pd.read_csv(mastersheetFile)
df_master
# Out:
#        subID         task  age sex condition  comprehension     transcript  \
# 0    sub-023  prettymouth   28   F    affair          0.889    prettymouth
# 1    sub-023     milkyway   28   F     vodka          1.000  milkywayvodka
# 2    sub-030  prettymouth   21   F  paranoia          0.963    prettymouth
# 3    sub-030     milkyway   21   F     vodka          0.893  milkywayvodka
# 4    sub-032  prettymouth   22   M    affair          0.963    prettymouth
# ..       ...          ...  ...  ..       ...            ...            ...
# 208  sub-314    piemanpni   25   F       NaN          0.767      piemanpni
# 209  sub-314        bronx   25   F       NaN          0.780          bronx
# 210  sub-314       forgot   25   F       NaN          0.780         forgot
# 211  sub-314        black   25   F       NaN          0.920          black
# 212  sub-315        black   35   M       NaN          0.600          black
#
#              label
# 0      prettymouth
# 1    milkywayvodka
# 2      prettymouth
# 3    milkywayvodka
# 4      prettymouth
# ..             ...
# 208      piemanpni
# 209          bronx
# 210         forgot
# 211          black
# 212          black
#
# [213 rows x 8 columns]

# %%
mastersheetFile = '/work/desai-lab/xuanyang/Project/Semantic/dissemination/github/DiscoFMRI/scripts/fMRI/master_event_10stories_highacc.csv'
df_event = pd.read_csv(mastersheetFile)
df_event
# Out:
#    Unnamed: 0  duration  onset           task         story  Nsubj  \
# 0           0      2225     14       21styear      21styear   10.0
# 1           1       533      8          black         black   47.0
# 2           2       357      8          bronx         bronx   47.0
# 3           3       558      8         forgot        forgot   47.0
# 4           6       269     14       milkyway      milkyway   34.0
# 5          11       267      8      piemanpni     piemanpni   47.0
# 6          12       451     14    prettymouth   prettymouth   35.0
# 7          14       272     33   shapessocial  shapessocial   58.0
# 8          16       602     20  slumlordreach      slumlord   16.0
# 9          17       550    646  slumlordreach         reach   16.0
#
#    comprehension  duration_min
# 0            1.0        55.625
# 1            1.0        13.325
# 2            1.0         8.925
# 3            1.0        13.950
# 4            1.0         6.725
# 5            1.0         6.675
# 6            1.0        11.275
# 7            1.0         6.800
# 8            1.0        15.050
# 9            1.0        13.750

# %%
import pandas as pd
import os
# df_timestamps = pd.read_csv('/work/desai-lab/xuanyang/Project/Semantic/analysis/ParametricModulation/Nastase/allstories/master/codes/Timestamps_10stories.csv')
df_timestamps = pd.read_csv('/work/desai-lab/xuanyang/Project/Semantic/dissemination/github/DiscoFMRI/scripts/fMRI/timings/df_timings_10transcripts.csv')
df_timestamps['word_lower'] = df_timestamps['word'].str.lower()
df_timestamps['idx'] = range(len(df_timestamps))
df_timestamps['functional'] = 1
List_content = ['JJ','JJR','JJS',
                'NN','NNS','NNP','NNPS',
                'POS','PRP','PRP$',
                'RB','RBR','RBS',
                'VB','VBG','VBN','VBD','VBP','VBZ']
df_timestamps.loc[df_timestamps.PoS.isin(List_content),'functional'] =0 
df_timestamps
# Out:
#         Word word_gentle       onset      offset  PoS   transcript  lemma  \
# 0       When        when    1.340000    1.500000  WRB  prettymouth   when
# 1        the         the   21.150000   21.250000   DT  prettymouth    the
# 2      phone       phone   21.250000   21.560000   NN  prettymouth  phone
# 3       rang        rang   21.560000   21.990000  VBD  prettymouth   rang
# 4        the         the   22.070000   22.190000   DT  prettymouth    the
# ...      ...         ...         ...         ...  ...          ...    ...
# 24653      C           c  818.280000  818.710000   NN       forgot      c
# 24654      D           d  819.809999  820.159999   NN       forgot      d
# 24655      E           e  821.540000  821.880000   NN       forgot      e
# 24656      F           f  822.969999  823.429999   NN       forgot      f
# 24657      G           g  824.450000  824.820000   NN       forgot      g
#
#         word  blankTR  onset_addblankTR  offset_addblankTR word_lower    idx  \
# 0       when        0          1.340000           1.500000       when      0
# 1        the        0         21.150000          21.250000        the      1
# 2      phone        0         21.250000          21.560000      phone      2
# 3       rang        0         21.560000          21.990000       rang      3
# 4        the        0         22.070000          22.190000        the      4
# ...      ...      ...               ...                ...        ...    ...
# 24653      c        8        830.280000         830.710000          c  24653
# 24654      d        8        831.809999         832.159999          d  24654
# 24655      e        8        833.540000         833.880000          e  24655
# 24656      f        8        834.969999         835.429999          f  24656
# 24657      g        8        836.450000         836.820000          g  24657
#
#        functional
# 0               1
# 1               1
# 2               0
# 3               0
# 4               1
# ...           ...
# 24653           0
# 24654           0
# 24655           0
# 24656           0
# 24657           0
#
# [24658 rows x 14 columns]

# %%
import os 
import pandas as pd
N_factors = 8
Dir_FA = os.path.join(Dir_github,project,'scripts','FactorAnalysis','output')
df_FA = pd.read_csv(os.path.join(Dir_FA,f'data_FA_n{N_factors}.csv'))
df_FA
# Out:
#           idx        Word    Lemma  Fam_Brys  OLD20F  OLD20  \
# 0          35     abandon  abandon  0.962963   7.450   2.90
# 1          36   abandoned  abandon  1.000000   6.329   3.55
# 2          39  abandoning  abandon  0.962963   6.956   3.70
# 3          41    abandons  abandon  0.962963   7.450   2.90
# 4         101     abdomen  abdomen  1.000000   6.386   3.00
# ...       ...         ...      ...       ...     ...    ...
# 13845  105919        zone     zone  1.000000   8.469   1.40
# 13846  105920       zoned     zone  1.000000   7.131   1.90
# 13847  105921       zones     zone  1.000000   7.791   1.65
# 13848  105922      zoning     zone  1.000000   7.259   2.00
# 13849  105945     zoology  zoology  1.000000   6.832   2.80
#
#        Mink_Perceptual_Lanc  CD_Blog_LemmaSum  Cumfreq_TASA  UniphonP_St  ...  \
# 0                  2.744282          3.132260     -0.735424     0.049831  ...
# 1                  3.075033          3.132260      1.035183     0.051145  ...
# 2                  2.744282          3.132260     -1.543549     0.051486  ...
# 3                  2.744282          3.132260     -0.735424     0.052438  ...
# 4                  4.602757          1.954243     -0.401581     0.047912  ...
# ...                     ...               ...           ...          ...  ...
# 13845              3.091321          3.145196      1.171116     0.042188  ...
# 13846              3.242207          3.145196      1.171116     0.044226  ...
# 13847              3.091321          3.145196     -0.383166     0.040259  ...
# 13848              4.005242          3.145196     -1.013596     0.044552  ...
# 13849              2.946429          1.380211     -1.852771     0.032578  ...
#
#        Consistency_Token_FB_C  Freqtraj_TASA     F1_n8     F2_n8     F3_n8  \
# 0                    0.917246       1.059894  0.160709  0.494050 -0.274023
# 1                    0.793056       0.935349  0.401931  0.861063 -0.301316
# 2                    0.957437       0.251768  0.140281  0.977217  0.500563
# 3                    0.917246       1.059894  0.088305  0.586460 -0.233246
# 4                    0.939005       0.660592 -1.213338  0.776602  0.812296
# ...                       ...            ...       ...       ...       ...
# 13845                0.025341       0.642419  0.630311 -1.515289  0.906688
# 13846                0.134066       0.642419  0.426644 -0.953676  0.654027
# 13847                0.248645       1.412152  0.551074 -1.029902  1.231030
# 13848                0.959106       0.781722  0.349154 -0.284680  1.725670
# 13849                0.975598      -0.057453 -2.143722  0.937833  0.443739
#
#           F4_n8     F5_n8     F6_n8     F7_n8     F8_n8
# 0     -0.803012  0.664840 -1.257531  0.975810 -0.240104
# 1     -0.770305  0.815986 -1.026902 -0.480004 -0.334186
# 2     -0.489144  1.047399 -1.298787  0.572348 -0.377726
# 3     -0.777023  0.948373 -1.173861  0.666396 -0.224983
# 4     -0.184771  0.160941  1.080471  0.503377  0.119304
# ...         ...       ...       ...       ...       ...
# 13845 -0.115375 -1.192884 -0.656951  1.207406 -0.510982
# 13846  0.334660 -0.938703 -0.647832 -0.982571 -1.007818
# 13847  0.183044 -0.861522 -0.619213  0.867422 -0.937866
# 13848 -0.042970  0.409334 -0.828881 -0.759834 -0.657826
# 13849  0.083175 -1.471271 -0.355091 -0.105980 -0.829105
#
# [13850 rows x 117 columns]

# %%
N_allwords = len(df_timestamps)
df_merge1 = df_timestamps.merge(df_FA, left_on="Word", right_on="Word", how="left")
df_merge2 = df_timestamps.merge(df_FA, left_on="word_gentle", right_on="Word", how="left")
df_merge12 = df_merge1.combine_first(df_merge2)
df_merge3 = df_timestamps.merge(df_FA, left_on="word_lower", right_on="Word", how="left")
df_merge123 = df_merge12.combine_first(df_merge3) # Use this one
df_merge4 = df_timestamps.merge(df_FA, left_on="lemma", right_on="Word", how="left")
df_merge1234 = df_merge123.combine_first(df_merge4) 

df_final = df_merge123.copy()
df_final
# Out:
#        AoA_Kuper  AoA_LWV  Arousal_NRC  Assoc_Freq_Token  Assoc_Freq_Token123  \
# 0            NaN      NaN          NaN               NaN                  NaN
# 1            NaN      NaN          NaN               NaN                  NaN
# 2           4.11  4.37255        0.344             742.0               1676.0
# 3           4.53  4.91959        0.427               3.0                 13.0
# 4            NaN      NaN          NaN               NaN                  NaN
# ...          ...      ...          ...               ...                  ...
# 24653        NaN      NaN          NaN               NaN                  NaN
# 24654        NaN      NaN          NaN               NaN                  NaN
# 24655        NaN      NaN          NaN               NaN                  NaN
# 24656        NaN      NaN          NaN               NaN                  NaN
# 24657        NaN      NaN          NaN               NaN                  NaN
#
#        Assoc_Freq_Type  Assoc_Freq_Type123  Auditory_Lanc  BigramF_Avg_C_Log  \
# 0                  NaN                 NaN            NaN                NaN
# 1                  NaN                 NaN            NaN                NaN
# 2                165.0               412.0       3.904762           3.066538
# 3                  3.0                 7.0       3.937500           3.193275
# 4                  NaN                 NaN            NaN                NaN
# ...                ...                 ...            ...                ...
# 24653              NaN                 NaN            NaN                NaN
# 24654              NaN                 NaN            NaN                NaN
# 24655              NaN                 NaN            NaN                NaN
# 24656              NaN                 NaN            NaN                NaN
# 24657              NaN                 NaN            NaN                NaN
#
#        BigramF_Avg_U_Log  ...    idx_y  lemma      offset  offset_addblankTR  \
# 0                    NaN  ...      NaN   when    1.500000           1.500000
# 1                    NaN  ...      NaN    the   21.250000          21.250000
# 2               4.364043  ...  70930.0  phone   21.560000          21.560000
# 3               4.593165  ...  77104.0   rang   21.990000          21.990000
# 4                    NaN  ...      NaN    the   22.190000          22.190000
# ...                  ...  ...      ...    ...         ...                ...
# 24653                NaN  ...      NaN      c  818.710000         830.710000
# 24654                NaN  ...      NaN      d  820.159999         832.159999
# 24655                NaN  ...      NaN      e  821.880000         833.880000
# 24656                NaN  ...      NaN      f  823.429999         835.429999
# 24657                NaN  ...      NaN      g  824.820000         836.820000
#
#             onset  onset_addblankTR   transcript   word  word_gentle  \
# 0        1.340000          1.340000  prettymouth   when         when
# 1       21.150000         21.150000  prettymouth    the          the
# 2       21.250000         21.250000  prettymouth  phone        phone
# 3       21.560000         21.560000  prettymouth   rang         rang
# 4       22.070000         22.070000  prettymouth    the          the
# ...           ...               ...          ...    ...          ...
# 24653  818.280000        830.280000       forgot      c            c
# 24654  819.809999        831.809999       forgot      d            d
# 24655  821.540000        833.540000       forgot      e            e
# 24656  822.969999        834.969999       forgot      f            f
# 24657  824.450000        836.450000       forgot      g            g
#
#        word_lower
# 0            when
# 1             the
# 2           phone
# 3            rang
# 4             the
# ...           ...
# 24653           c
# 24654           d
# 24655           e
# 24656           f
# 24657           g
#
# [24658 rows x 132 columns]

# %%
List_vars_default = ['word','transcript','PoS','functional']
NFA=8
List_vars = [f'F{x}_n{NFA}' for x in range(1,NFA+1)]
df_final[List_vars_default+List_vars].dropna()
# Out:
#          word   transcript  PoS  functional     F1_n8     F2_n8     F3_n8  \
# 2       phone  prettymouth   NN           0  1.763911 -1.044677 -0.653705
# 3        rang  prettymouth  VBD           0  1.030902 -2.020637  0.719832
# 7         man  prettymouth   NN           0  2.851192 -2.288231  2.684006
# 8       asked  prettymouth  VBD           0  2.463283 -0.468228  2.240429
# 10       girl  prettymouth   NN           0  1.813931 -0.874200 -1.155023
# ...       ...          ...  ...         ...       ...       ...       ...
# 24639     can       forgot   MD           1  3.487860 -2.076439  2.267891
# 24641  filled       forgot  VBN           0  1.591311 -1.474903  0.855149
# 24646    dear       forgot   JJ           0  1.119555 -2.038851 -1.507765
# 24648    hear       forgot  VBP           0  2.320631 -2.035110 -1.366618
# 24650  prayer       forgot   NN           0  0.500763 -0.882939 -2.386480
#
#           F4_n8     F5_n8     F6_n8     F7_n8     F8_n8
# 2     -0.189395 -0.391140  1.571162  0.064259  2.203828
# 3      0.354703 -0.743739 -0.802099 -1.123645 -0.360688
# 7     -0.302017  1.143151  1.251987  2.130608  8.788365
# 8      0.312553 -0.657099 -1.203714 -1.241680  0.092613
# 10    -0.975277 -1.255693  1.454110  2.441979  5.332704
# ...         ...       ...       ...       ...       ...
# 24639 -0.077441  2.412652  0.322451  0.423603  0.952550
# 24641  1.061574  0.270031 -0.029611 -0.788262 -0.663085
# 24646 -1.532247  0.565277 -0.932972 -0.302120  0.096876
# 24648 -1.728844 -0.052322 -1.137643  0.173028  0.932585
# 24650 -1.116343 -0.809295 -0.156330  0.965756  0.911619
#
# [8777 rows x 12 columns]

# %%
df_table = df_final[['word','transcript']].dropna().groupby(['transcript']).count()
df_table['tokens_analyze'] = df_final[['F1_n8','onset','transcript']].dropna().groupby(['transcript']).count()['F1_n8']
df_table['tokens_analyze%'] = df_table['tokens_analyze']/df_table['word']*100
df_table['tokens_analyze%'] = df_table['tokens_analyze%'].round(2)
df_table.reset_index(inplace=True)
print('Milkyway: average')
print(df_table.loc[df_table['transcript'].str.contains('milkyway'),['word','tokens_analyze','tokens_analyze%']].mean())
df_table
# Out:
# Milkyway: average
# word               1058.50
# tokens_analyze      369.00
# tokens_analyze%      34.86
# dtype: float64
#          transcript  word  tokens_analyze  tokens_analyze%
# 0          21styear  8267            3101            37.51
# 1             black  1544             538            34.84
# 2             bronx  1379             426            30.89
# 3            forgot  2135             742            34.75
# 4  milkywayoriginal  1059             364            34.37
# 5     milkywayvodka  1058             374            35.35
# 6         piemanpni   992             328            33.06
# 7       prettymouth  1970             638            32.39
# 8      shapessocial   910             394            43.30
# 9     slumlordreach  5344            1808            33.83

# %%
# Out:
# word               1061.000000
# tokens_analyze      365.333333
# tokens_analyze%      34.433333
# dtype: float64

# %%
df_table['tokens_analyze'].sum()
# Out:
# 11609

# %%
df_tokens_summary = pd.DataFrame()
for i,df,label in zip(range(5),[df_timestamps,df_merge1,df_merge12,df_merge123,df_merge1234],
                     ['raw','Word','Word_gentle','word_lower','lemma']):
    df_tokens_summary.loc[i,'label'] = label
    df_tokens_summary.loc[i,'tokens_all'] = df[['Word']+[x for x in df.columns if x.startswith('F') and '_n' in x]].dropna()['Word'].shape[0]
    df_tokens_summary.loc[i,'words_all'] = df[['Word']+[x for x in df.columns if x.startswith('F') and '_n' in x]].dropna()['Word'].unique().shape[0]
    df_tokens_summary.loc[i,'tokens_content'] = df[['Word']+[x for x in df.columns if x.startswith('F') and '_n' in x]].dropna().loc[df['functional']==0,'Word'].shape[0]
    df_tokens_summary.loc[i,'words_content'] = df[['Word']+[x for x in df.columns if x.startswith('F') and '_n' in x]].dropna().loc[df['functional']==0,'Word'].unique().shape[0]
    
#     print(f"all words: {N_all_tokens} tokens, {N_all_words} words")
#     print(f"content words: {N_content_tokens} tokens, {N_content_words} words")
for var in ['tokens_all','words_all','tokens_content','words_content']:
    df_tokens_summary[var+'%']  = df_tokens_summary[var]/df_tokens_summary.loc[0,var]
df_tokens_summary
# Out:
#          label  tokens_all  words_all  tokens_content  words_content  \
# 0          raw     24658.0     3917.0         17123.0         3738.0
# 1         Word      8427.0     2124.0          8064.0         2107.0
# 2  Word_gentle      8776.0     2309.0          8395.0         2286.0
# 3   word_lower      8777.0     2310.0          8396.0         2287.0
# 4        lemma      8792.0     2321.0          8411.0         2298.0
#
#    tokens_all%  words_all%  tokens_content%  words_content%
# 0     1.000000    1.000000         1.000000        1.000000
# 1     0.341755    0.542252         0.470946        0.563670
# 2     0.355909    0.589482         0.490276        0.611557
# 3     0.355949    0.589737         0.490335        0.611825
# 4     0.356558    0.592545         0.491211        0.614767

# %%
Dir_working = '/work/desai-lab/xuanyang/Project/Semantic/analysis/ParametricModulation/Nastase/allstories/FactorAnalysis'
Nvar = 113
NFA = 8
flag_model = f'Nvar{Nvar}NFA{NFA}_LPAC_multipleReg'

List_vars_default = ['word','onset','transcript','PoS','functional']

mask_PAC_L = '/work/desai-lab/xuanyang/Project/dataset/Nastase/codes/mask/final/rs_HCP_AuditoryMask_L_sm6_100.nii.gz'
mask_PAC_R = '/work/desai-lab/xuanyang/Project/dataset/Nastase/codes/mask/final/rs_HCP_AuditoryMask_R_sm6_100.nii.gz'

List_vars = [f'F{x}_n{NFA}' for x in range(1,NFA+1)]
    
Dir_model = os.path.join(Dir_working,'models',flag_model,f'FA{NFA}')
Dir_results = os.path.join(Dir_model,'results')
Dir_results_1st = os.path.join(Dir_results,'firstlevel')
Dir_results_2nd = os.path.join(Dir_results,'secondlevel')
if not os.path.exists(Dir_results):
    os.makedirs(Dir_results)
if not os.path.exists(Dir_results_1st):
    os.makedirs(Dir_results_1st)
    
Dir_scriptsToRun = os.path.join(Dir_model,'codes','scriptsToRun')
if not os.path.exists(Dir_scriptsToRun):
    os.makedirs(Dir_scriptsToRun)
Dir_log = os.path.join(Dir_model,'codes','logs')
if not os.path.exists(Dir_log):
    os.makedirs(Dir_log)
for i,subID, task,label in zip(df_master.index,df_master.subID,df_master.task,df_master.label):
    idx = "{:03d}".format(i+1)

    df_event = pd.read_csv(df_master.loc[i,'event'],sep='\t')
    blankSecs = df_event.loc[0,'onset']
    df_timestamps_tmp = df_final.loc[df_final['transcript']==label,List_vars_default+List_vars].reset_index(drop=True)
    df_timestamps_tmp['onset'] = df_timestamps_tmp['onset'] + blankSecs
    df_timestamps_tmp['missing'] = 1
    df_timestamps_tmp.loc[df_timestamps_tmp[List_vars].notna().all(axis=1),'missing'] = 0

    Dir_sub = os.path.join(Dir_results_1st,subID)
    if not os.path.exists(Dir_sub):
        os.makedirs(Dir_sub)
    Dir_sub_task = os.path.join(Dir_sub,task)
    if not os.path.exists(Dir_sub_task):
        os.makedirs(Dir_sub_task)

    ### Timings
    # missing
    df_tmp = df_timestamps_tmp.loc[df_timestamps_tmp.missing==1]
    df_tmp.to_csv(os.path.join(Dir_sub_task,'{}_{}_missing.csv'.format(subID,task)),index=False)
    List_output = df_tmp.onset.astype(str).values
    path_missing = os.path.join(Dir_sub_task,'{}_{}_missing.1D'.format(subID,task))
    with open(path_missing,'w') as f:
        f.writelines('\n'.join(List_output))

    # content words
    df_tmp = df_timestamps_tmp.loc[(df_timestamps_tmp.functional==0)&(df_timestamps_tmp.missing==0)]
    df_tmp.to_csv(os.path.join(Dir_sub_task,'{}_{}_cont.csv'.format(subID,task)),index=False)
    List_tmp = [','.join(x) for x in df_tmp[List_vars].astype(str).values]
    List_output =  [x+'*'+y for x,y in zip(df_tmp.onset.astype(str),List_tmp)] 
    path_cont = os.path.join(Dir_sub_task,'{}_{}_cont.1D'.format(subID,task))
    with open(path_cont,'w') as f:
        f.writelines('\n'.join(List_output))

    # functional words
    df_tmp = df_timestamps_tmp.loc[(df_timestamps_tmp.functional==1)&(df_timestamps_tmp.missing==0)]
    df_tmp.to_csv(os.path.join(Dir_sub_task,'{}_{}_func.csv'.format(subID,task)),index=False)
    List_output =  df_tmp.onset.astype(str).values
    path_func = os.path.join(Dir_sub_task,'{}_{}_func.1D'.format(subID,task))
    with open(path_func,'w') as f:
        f.writelines('\n'.join(List_output))


    ### Confounding variables
    path_confounds = df_master.loc[i,'confounding']
    df_confounds = pd.read_csv(path_confounds,sep='\t')
    df_motions = df_confounds[['trans_x','trans_y','trans_z','rot_x','rot_y','rot_z']].copy()
    path_motion = os.path.join(Dir_sub_task,'motions_6.1D')
    #if not os.path.exists(path_motion):
    df_motions.to_csv(path_motion,index=False,header=False,sep=' ')
    list_outlier = [outlier for outlier in df_confounds.columns if 'motion_outlier' in outlier]
    df_confounds['motion_outlier'] = 1-df_confounds[list_outlier].sum(axis=1)
    path_motion_outlier = os.path.join(Dir_sub_task,'motions_outlier.1D')
    df_confounds['motion_outlier'].to_csv(path_motion_outlier,index=False,header=False,sep=' ')

    
    img_smooth = df_master.loc[i,'smooth_clean_rs']
    scriptFile = os.path.join(Dir_sub_task,'Batch_firstlevel_{}_{}.sh'.format(subID,task))
    with open(scriptFile, "w") as f:
            f.write("#!/bin/tcsh\n")
            f.write("/work/apps/AFNI/linux_openmp_64/afni_proc.py -subj_id {} \\\n".format(subID))
            f.write("-scr_overwrite -blocks mask regress \\\n")
            f.write("-mask_import PAC_L {} \\\n".format(mask_PAC_L))
            f.write("-dsets {} \\\n".format(img_smooth))
            f.write("-regress_stim_times {} {} {} \\\n".format(path_cont,path_func,path_missing))
            f.write("-regress_basis 'TENT(1.5,7.5,5)' \\\n")
#                 f.write("-regress_ROI {} {} \\\n".format('PAC_L','PAC_R'))
            f.write("-regress_ROI {} \\\n".format('PAC_L'))
            f.write("-regress_stim_types AM2 times times \\\n")
            f.write("-regress_stim_labels cont func missing \\\n")
            f.write("-regress_opts_3dD -jobs 6 \\\n")
            for iFA in range(1,NFA+1):
                f.write(f"-gltsym 'SYM: cont[{1+5*iFA}] +cont[{2+5*iFA}] +cont[{3+5*iFA}] +cont[{4+5*iFA}]' -glt_label {iFA} FA{iFA}_bin2345 \\\n")
            f.write("-regress_polort 0 \\\n")
            f.write("-regress_3dD_stop \\\n")
            f.write("-regress_reml_exec \\\n")
            f.write("-regress_make_ideal_sum sum_ideal.1D \\\n")
            f.write("-regress_run_clustsim no \\\n")
            f.write("\n")

    masterScript = os.path.join(Dir_scriptsToRun,'run_Batch_firstlevel_{}.sh'.format(idx))
    with open(masterScript, "w") as f:
        f.write("#!/bin/tcsh\n")
        f.write("cd {} \n".format(Dir_sub_task))
        f.write("tcsh {} \n".format(scriptFile))
        f.write("tcsh proc.{} \n".format(subID))
        f.write("rm {}/{}.results/pb00.* \n".format(Dir_sub_task,subID))
        f.write("rm {}/{}.results/all_runs.* \n".format(Dir_sub_task,subID))
        f.write("rm {}/{}.results/fitts.* \n".format(Dir_sub_task,subID))
        f.write("rm {}/{}.results/errts.* \n".format(Dir_sub_task,subID))
    print(iFA,idx,subID)

Dir_codes = os.path.join(Dir_model,'codes')

if not os.path.exists(Dir_log):
    os.makedirs(Dir_log)

jobname = flag_model
ncores = 6
partition = 'desailab-48core'
path_output = os.path.join(Dir_log,jobname)
script_slurm = os.path.join(Dir_codes,'Batch_slurm_firstlevel.sh')
array = '001-213'
#array = '001-013'
with open(script_slurm, "w") as f:
    f.write("#!/bin/sh\n")
    f.write("### name your job \n")
    f.write("#SBATCH --job-name={} \n".format(jobname))
    f.write("### specify number of cores to use \n")
    f.write("#SBATCH -n {} \n".format(ncores))
    f.write("#SBATCH -N 1 \n".format(ncores))
    f.write("### which partition do you want to use? \n")
    f.write("#SBATCH -p {} \n".format(partition))
    f.write("### %a specifies that the output file for each subject will be named according to their array ID \n")
    f.write("# Where to output log files? \n")
    f.write("#SBATCH --output='{}-%A_%a.log' \n".format(path_output))
    f.write("#SBATCH --error='{}-%A_%a.err' \n".format(path_output))
    f.write("### list the subjects that you want to submit in this array \n")
    f.write("#SBATCH --array={} \n".format(array))
    f.write("module load afni \n")
    f.write("module load python3/anaconda/2021.11 \n")
    f.write('echo "Slurm job ID: " $SLURM_JOB_ID \n')
    f.write('echo "Slurm array task ID: " $SLURM_ARRAY_TASK_ID \n')

    f.write('printf -v subj "%03d" $SLURM_ARRAY_TASK_ID \n')
    f.write('echo "Running firstlevel regression on sub-$subj" \n')
    f.write('cd {} \n'.format(Dir_scriptsToRun))
    f.write('tcsh run_Batch_firstlevel_$subj.sh \n')
    f.write('echo "Finished firstlevel regression sub-$subj" \n')
    f.write('date \n')
# Out:
# 8 001 sub-023
# 8 002 sub-023
# 8 003 sub-030
# 8 004 sub-030
# 8 005 sub-032
# 8 006 sub-032
# 8 007 sub-034
# 8 008 sub-034
# 8 009 sub-049
# 8 010 sub-050
# 8 011 sub-052
# 8 012 sub-052
# 8 013 sub-058
# 8 014 sub-065
# 8 015 sub-066
# 8 016 sub-075
# 8 017 sub-079
# 8 018 sub-079
# 8 019 sub-081
# 8 020 sub-081
# 8 021 sub-083
# 8 022 sub-083
# 8 023 sub-084
# 8 024 sub-086
# 8 025 sub-086
# 8 026 sub-087
# 8 027 sub-087
# 8 028 sub-088
# 8 029 sub-088
# 8 030 sub-089
# 8 031 sub-089
# 8 032 sub-090
# 8 033 sub-090
# 8 034 sub-091
# 8 035 sub-091
# 8 036 sub-093
# 8 037 sub-093
# 8 038 sub-095
# 8 039 sub-095
# 8 040 sub-096
# 8 041 sub-096
# 8 042 sub-097
# 8 043 sub-097
# 8 044 sub-098
# 8 045 sub-098
# 8 046 sub-099
# 8 047 sub-099
# 8 048 sub-100
# 8 049 sub-100
# 8 050 sub-101
# 8 051 sub-101
# 8 052 sub-102
# 8 053 sub-102
# 8 054 sub-103
# 8 055 sub-103
# 8 056 sub-104
# 8 057 sub-104
# 8 058 sub-106
# 8 059 sub-106
# 8 060 sub-107
# 8 061 sub-107
# 8 062 sub-108
# 8 063 sub-108
# 8 064 sub-109
# 8 065 sub-109
# 8 066 sub-110
# 8 067 sub-110
# 8 068 sub-111
# 8 069 sub-111
# 8 070 sub-127
# 8 071 sub-127
# 8 072 sub-131
# 8 073 sub-136
# 8 074 sub-143
# 8 075 sub-145
# 8 076 sub-186
# 8 077 sub-190
# 8 078 sub-190
# 8 079 sub-201
# 8 080 sub-221
# 8 081 sub-222
# 8 082 sub-223
# 8 083 sub-225
# 8 084 sub-228
# 8 085 sub-229
# 8 086 sub-230
# 8 087 sub-231
# 8 088 sub-232
# 8 089 sub-233
# 8 090 sub-234
# 8 091 sub-235
# 8 092 sub-235
# 8 093 sub-236
# 8 094 sub-237
# 8 095 sub-244
# 8 096 sub-249
# 8 097 sub-265
# 8 098 sub-265
# 8 099 sub-265
# 8 100 sub-265
# 8 101 sub-265
# 8 102 sub-267
# 8 103 sub-267
# 8 104 sub-267
# 8 105 sub-268
# 8 106 sub-272
# 8 107 sub-273
# 8 108 sub-273
# 8 109 sub-273
# 8 110 sub-273
# 8 111 sub-274
# 8 112 sub-274
# 8 113 sub-274
# 8 114 sub-274
# 8 115 sub-275
# 8 116 sub-275
# 8 117 sub-275
# 8 118 sub-275
# 8 119 sub-279
# 8 120 sub-280
# 8 121 sub-280
# 8 122 sub-280
# 8 123 sub-284
# 8 124 sub-284
# 8 125 sub-284
# 8 126 sub-284
# 8 127 sub-285
# 8 128 sub-285
# 8 129 sub-285
# 8 130 sub-285
# 8 131 sub-286
# 8 132 sub-286
# 8 133 sub-287
# 8 134 sub-288
# 8 135 sub-288
# 8 136 sub-288
# 8 137 sub-288
# 8 138 sub-289
# 8 139 sub-289
# 8 140 sub-290
# 8 141 sub-290
# 8 142 sub-290
# 8 143 sub-290
# 8 144 sub-291
# 8 145 sub-291
# 8 146 sub-291
# 8 147 sub-291
# 8 148 sub-292
# 8 149 sub-292
# 8 150 sub-292
# 8 151 sub-292
# 8 152 sub-293
# 8 153 sub-294
# 8 154 sub-294
# 8 155 sub-294
# 8 156 sub-294
# 8 157 sub-295
# 8 158 sub-295
# 8 159 sub-295
# 8 160 sub-297
# 8 161 sub-298
# 8 162 sub-298
# 8 163 sub-298
# 8 164 sub-298
# 8 165 sub-299
# 8 166 sub-299
# 8 167 sub-300
# 8 168 sub-300
# 8 169 sub-301
# 8 170 sub-301
# 8 171 sub-301
# 8 172 sub-301
# 8 173 sub-302
# 8 174 sub-302
# 8 175 sub-303
# 8 176 sub-303
# 8 177 sub-304
# 8 178 sub-304
# 8 179 sub-304
# 8 180 sub-304
# 8 181 sub-305
# 8 182 sub-305
# 8 183 sub-306
# 8 184 sub-306
# 8 185 sub-307
# 8 186 sub-307
# 8 187 sub-307
# 8 188 sub-308
# 8 189 sub-308
# 8 190 sub-308
# 8 191 sub-308
# 8 192 sub-309
# 8 193 sub-309
# 8 194 sub-309
# 8 195 sub-309
# 8 196 sub-310
# 8 197 sub-310
# 8 198 sub-310
# 8 199 sub-310
# 8 200 sub-311
# 8 201 sub-312
# 8 202 sub-312
# 8 203 sub-312
# 8 204 sub-312
# 8 205 sub-313
# 8 206 sub-313
# 8 207 sub-313
# 8 208 sub-313
# 8 209 sub-314
# 8 210 sub-314
# 8 211 sub-314
# 8 212 sub-314
# 8 213 sub-315
